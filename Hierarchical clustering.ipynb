# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %%
X = np.array([[1, 3],
             [2, 4],
             [1, 5],
             [5, 5],
             [5, 7],
             [4, 9],
             [2, 8],
             [3, 10],
            ])
n, m = X.shape

# %%
from math import dist

D = np.zeros([n, n])
for i in range(n):
    for j in range(n):
        D[i, j] = dist(X[i], X[j])
np.round(D, 3)
# Out:
# array([[0.   , 1.414, 2.   , 4.472, 5.657, 6.708, 5.099, 7.28 ],
#        [1.414, 0.   , 1.414, 3.162, 4.243, 5.385, 4.   , 6.083],
#        [2.   , 1.414, 0.   , 4.   , 4.472, 5.   , 3.162, 5.385],
#        [4.472, 3.162, 4.   , 0.   , 2.   , 4.123, 4.243, 5.385],
#        [5.657, 4.243, 4.472, 2.   , 0.   , 2.236, 3.162, 3.606],
#        [6.708, 5.385, 5.   , 4.123, 2.236, 0.   , 2.236, 1.414],
#        [5.099, 4.   , 3.162, 4.243, 3.162, 2.236, 0.   , 2.236],
#        [7.28 , 6.083, 5.385, 5.385, 3.606, 1.414, 2.236, 0.   ]])

# %% [markdown]
# Lo anterior es la forma de calcurar la matriz $D$, sin embargo utilizaremos las librerías para hacer el dendograma y el cluster analysis.

# %%
dendrogram = sch.dendrogram(sch.linkage(X, method='complete'))

# %%
hc = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='complete')
y_hc = hc.fit_predict(X)
plt.scatter(X[y_hc==0, 0], X[y_hc == 0, 1], s=50, color='red')
plt.scatter(X[y_hc==1, 0], X[y_hc == 1, 1], s=50, color='blue')
plt.scatter(X[y_hc==2, 0], X[y_hc == 2, 1], s=50, color='green')
# plt.scatter(X[y_hc==3, 0], X[y_hc == 3, 1], s=50, color='yellow')

# %%
X = np.random.random([50, 2])

# %% [markdown]
# $\text{single-linkage}$

# %%
dendrogram = sch.dendrogram(sch.linkage(X, method='single'))

# %%
hc = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='single')
y_hc = hc.fit_predict(X)
plt.scatter(X[y_hc==0, 0], X[y_hc == 0, 1], s=50, color='red')
plt.scatter(X[y_hc==1, 0], X[y_hc == 1, 1], s=50, color='blue')
plt.scatter(X[y_hc==2, 0], X[y_hc == 2, 1], s=50, color='green')

# %% [markdown]
# $\text{average-linkage}$

# %%
dendrogram = sch.dendrogram(sch.linkage(X, method='average'))

# %%
hc = AgglomerativeClustering(n_clusters=4, affinity='euclidean', linkage='average')
y_hc = hc.fit_predict(X)
plt.scatter(X[y_hc==0, 0], X[y_hc == 0, 1], s=50, color='red')
plt.scatter(X[y_hc==1, 0], X[y_hc == 1, 1], s=50, color='blue')
plt.scatter(X[y_hc==2, 0], X[y_hc == 2, 1], s=50, color='green')
plt.scatter(X[y_hc==3, 0], X[y_hc == 3, 1], s=50, color='yellow')
plt.scatter(X[y_hc==4, 0], X[y_hc == 4, 1], s=50, color='pink')

# %% [markdown]
# $\text{complete-linkage}$

# %%
dendrogram = sch.dendrogram(sch.linkage(X, method='complete'))

# %%
hc = AgglomerativeClustering(n_clusters=4, affinity='euclidean', linkage='complete')
y_hc = hc.fit_predict(X)
plt.scatter(X[y_hc==0, 0], X[y_hc == 0, 1], s=50, color='red')
plt.scatter(X[y_hc==1, 0], X[y_hc == 1, 1], s=50, color='blue')
plt.scatter(X[y_hc==2, 0], X[y_hc == 2, 1], s=50, color='green')
plt.scatter(X[y_hc==3, 0], X[y_hc == 3, 1], s=50, color='yellow')
